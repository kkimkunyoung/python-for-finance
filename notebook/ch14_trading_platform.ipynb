# %% [markdown]
# # 14 FXCM 트레이딩 플랫폼

# %% [markdown]
# ## 14.1 시작하기

# %% [markdown]
# ## 14.2 데이터 받기

# %% [markdown]
# ### 14.2.1 틱 데이터 받기

# %% [markdown]
# ### 14.2.2 캔들 데이터 받기

# %% [markdown]
# ## 14.3 API 다루기

# %% [markdown]
# ### 14.3.1 과거 데이터 받기

# %% [markdown]
# ### 14.3.2 스트리밍 데이터 받기

# %% [markdown]
# ### 14.3.3 주문하기

# %% [markdown]
# ### 14.3.4 계좌 정보 조회하기
